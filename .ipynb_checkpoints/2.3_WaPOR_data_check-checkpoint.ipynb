# %% [markdown]
# # WaPOR data check
#
# ## 1. Does RS-derived Precipitation data agree with in-situ measurement?
# ### Example: Extract point time series from raster maps
# Sometimes, we can obtain precipitation measurement from in-situ meteorological monitoring station or from global database (For example, NOAA Global Historical Climatology Network). This data can be used to validate remotely sensed precipitation data.
# First, we'll read data from a text file or spread sheet. Using python code, this can be done systematically. For example, below is a code to read data from the given csv file.

# %%
import numpy as np
import os

ts_fh=r"D:\FAO\Training\ETH_1907\Material\Data\Others\Jordan\BEER SHEVA.csv"

# Read station name
Station_name=os.path.split(ts_fh)[-1].split(".")[0]
print(Station_name)

# Read metadata (coordinates)
f = open(ts_fh,'r') #open file to read
first=f.readline().split(";")
LatLon=[float(first[1]),float(first[3])]
f.close()
print(LatLon)

# Read data
obs_data=np.loadtxt(ts_fh,delimiter=';',skiprows=1,usecols=(1,2,4))
obs_ts=pd.DataFrame(obs_data,columns=['Year','Month','Data'])
obs_ts
# Out:
# BEER SHEVA
# [31.25, 34.8164]
#         Year  Month    Data
# 0     1921.0    9.0 -9999.0
# 1     1921.0   10.0     1.1
# 2     1921.0   11.0     7.4
# 3     1921.0   12.0    55.7
# 4     1922.0    1.0    51.7
# 5     1922.0    2.0     0.0
# 6     1922.0    3.0    19.4
# 7     1922.0    4.0     1.3
# 8     1922.0    5.0     0.0
# 9     1922.0    6.0     0.0
# 10    1922.0    7.0     0.0
# 11    1922.0    8.0     0.0
# 12    1922.0    9.0     0.0
# 13    1922.0   10.0     0.0
# 14    1922.0   11.0     2.8
# 15    1922.0   12.0    62.7
# 16    1923.0    1.0    25.9
# 17    1923.0    2.0    43.0
# 18    1923.0    3.0     0.2
# 19    1923.0    4.0     9.9
# 20    1923.0    5.0     0.0
# 21    1923.0    6.0     0.0
# 22    1923.0    7.0     0.0
# 23    1923.0    8.0     0.0
# 24    1923.0    9.0     0.0
# 25    1923.0   10.0     7.5
# 26    1923.0   11.0     0.0
# 27    1923.0   12.0    21.0
# 28    1924.0    1.0    22.1
# 29    1924.0    2.0    29.3
# ...      ...    ...     ...
# 1107  2013.0   12.0   146.0
# 1108  2014.0    1.0     4.7
# 1109  2014.0    2.0     3.2
# 1110  2014.0    3.0    69.6
# 1111  2014.0    4.0     0.0
# 1112  2014.0    5.0    35.1
# 1113  2014.0    6.0     0.0
# 1114  2014.0    7.0     0.0
# 1115  2014.0    8.0     0.0
# 1116  2014.0    9.0     0.0
# 1117  2014.0   10.0    11.6
# 1118  2014.0   11.0    36.3
# 1119  2014.0   12.0    12.9
# 1120  2015.0    1.0    86.9
# 1121  2015.0    2.0    85.5
# 1122  2015.0    3.0     6.6
# 1123  2015.0    4.0     9.1
# 1124  2015.0    5.0     0.4
# 1125  2015.0    6.0     0.0
# 1126  2015.0    7.0     0.0
# 1127  2015.0    8.0     0.0
# 1128  2015.0    9.0     0.0
# 1129  2015.0   10.0    22.8
# 1130  2015.0   11.0    27.2
# 1131  2015.0   12.0    43.7
# 1132  2016.0    1.0    77.9
# 1133  2016.0    2.0    45.4
# 1134  2016.0    3.0     9.8
# 1135  2016.0    4.0    28.0
# 1136  2016.0    5.0 -9999.0
#
# [1137 rows x 3 columns]

# %% [markdown]
# For a selected month and year, the observed value can be obtained from the dataframe by *.loc* method.

# %%
obs_ts.loc[obs_ts['Year']==year].loc[obs_ts['Month']==month]
# Out:
#         Year  Month  Data
# 1049  2009.0    2.0  66.2

# %% [markdown]
# When we know the coordinates of the station, we can extract the corresponding value in a raster map (RS data) for later comparison. Below is the example function *PixelCoordinates* to get corresponding row and column index of a point in raster mapset given the geographical coordinate.

# %%
import glob
from osgeo import gdal
def PixelCoordinates(lon,lat,fh):
    """
    Find the corresponding pixel to a latitude and longitude.
    
    Parameters
    ----------
    lon : float or int
        Longitude to find.
    lat : float or int
        Latitude to find.
    fh : str
        Filehandle pointing to the file to be searched.
        
    Returns
    -------
    xpixel : int
        The index of the longitude.
    ypixel : int
        The index of the latitude.
    """
    SourceDS = gdal.Open(fh, gdal.GA_ReadOnly)
    xsize = SourceDS.RasterXSize
    ysize = SourceDS.RasterYSize
    GeoT = SourceDS.GetGeoTransform()
    assert (lon >= GeoT[0]) & (lon <= GeoT[0] + xsize * GeoT[1]), 'longitude is not on the map'
    assert (lat <= GeoT[3]) & (lat >= GeoT[3] + ysize * GeoT[5]), 'latitude is not on the map'
    location = GeoT[0]
    xpixel = -1
    while location <= lon:
        location += GeoT[1]
        xpixel += 1
    location = GeoT[3]
    ypixel = -1
    while location >= lat:
        location += GeoT[5]
        ypixel += 1
    return xpixel, ypixel   

P_fhs=glob.glob(r'D:\FAO\Training\ETH_1907\Material\Data\Others\Jordan\P\*.tif')
fh=P_fhs[1]
print(fh)
year=int(os.path.split(fh)[1].split("_")[-1][0:4])
month=int(os.path.split(fh)[1].split("_")[-1][4:6])
print(year,month)
xy=PixelCoordinates(LatLon[1],LatLon[0],fh)
print(xy)
# Out:
# D:\FAO\Training\ETH_1907\Material\Data\Others\Jordan\P\0_L1_monthly_PCP_200902.tif
# (2009, 2)
# (174, 1060)

# %% [markdown]
# Once obtain the row and column index in raster array from the point coordinates, we can extract the value at the point from the array. For example, below is the code to get the remotely sensed value at Beer Sheva station from the Precipitation raster file.

# %%
def OpenRasterAsArray(in_fh,nan_value=True,bandnumber=1,dtype='float32'):  
    datatypes = {"uint8": np.uint8, "int8": np.int8, "uint16": np.uint16, "int16":  np.int16, "Int16":  np.int16, "uint32": np.uint32,
    "int32": np.int32, "float32": np.float32, "float64": np.float64, "complex64": np.complex64, "complex128": np.complex128,
    "Int32": np.int32, "Float32": np.float32, "Float64": np.float64, "Complex64": np.complex64, "Complex128": np.complex128,}
    SourceDataSet = gdal.Open(in_fh, gdal.GA_ReadOnly)    
    Subdataset = SourceDataSet.GetRasterBand(bandnumber)
    NDV = Subdataset.GetNoDataValue()
    if NDV is None:
        NDV=-9999
    Array = Subdataset.ReadAsArray().astype(dtype)
    if nan_value:
        Array[Array == NDV] = np.nan
    return Array

map_array=OpenRasterAsArray(fh)
px_value=map_array[xy[1]][xy[0]]
print(px_value)
# Out:
# 57.0

# %% [markdown]
# ### Exercise (+)
# Extract a time series from the raster dataset at the location of the meteorological station. Store data in a dataframe.
#
# **Hint**:
# You can loop over the list of raster files and append a list of year, month, data.

# %%
years=[]
months=[]
values=[]
for fh in P_fhs:
    years.append(int(os.path.split(fh)[1].split("_")[-1][0:4]))
    months.append(int(os.path.split(fh)[1].split("_")[-1][4:6]))
    xy=PixelCoordinates(LatLon[1],LatLon[0],fh)
    map_array=OpenRasterAsArray(fh)
    px_value=map_array[xy[1]][xy[0]]
    values.append(px_value)
rs_ts=pd.DataFrame({'Year':years,'Month':months,'Data':values})
rs_ts
# Out:
#           Data  Month  Year
# 0    23.200001      1  2009
# 1    57.000000      2  2009
# 2    29.400000      3  2009
# 3     2.400000      4  2009
# 4     1.500000      5  2009
# 5     0.000000      6  2009
# 6     0.000000      7  2009
# 7     0.000000      8  2009
# 8     0.000000      9  2009
# 9     6.600000     10  2009
# 10   17.600000     11  2009
# 11   21.900000     12  2009
# 12   65.599998      1  2010
# 13   49.200001      2  2010
# 14   20.500000      3  2010
# 15    0.000000      4  2010
# 16    0.600000      5  2010
# 17    0.000000      6  2010
# 18    0.000000      7  2010
# 19    0.000000      8  2010
# 20    0.200000      9  2010
# 21    0.000000     10  2010
# 22    9.100000     11  2010
# 23   18.900000     12  2010
# 24   37.500000      1  2011
# 25   49.400002      2  2011
# 26   23.600000      3  2011
# 27    5.100000      4  2011
# 28    1.300000      5  2011
# 29    0.000000      6  2011
# ..         ...    ...   ...
# 90    0.000000      7  2016
# 91    0.000000      8  2016
# 92    0.000000      9  2016
# 93    7.700000     10  2016
# 94   16.600000     11  2016
# 95   51.299999     12  2016
# 96   51.200001      1  2017
# 97   55.900002      2  2017
# 98   16.200001      3  2017
# 99    6.700000      4  2017
# 100   1.300000      5  2017
# 101   0.000000      6  2017
# 102   0.000000      7  2017
# 103   0.000000      8  2017
# 104   0.000000      9  2017
# 105   6.300000     10  2017
# 106  19.000000     11  2017
# 107  34.599998     12  2017
# 108  80.300003      1  2018
# 109  52.299999      2  2018
# 110  15.900000      3  2018
# 111   0.700000      4  2018
# 112   2.100000      5  2018
# 113   0.000000      6  2018
# 114   0.000000      7  2018
# 115   0.000000      8  2018
# 116   0.800000      9  2018
# 117   1.200000     10  2018
# 118  28.000000     11  2018
# 119  36.400002     12  2018
#
# [120 rows x 3 columns]

# %% [markdown]
# ### Example: Compare RS-derived time series with observation
# Sometimes, observation and remote sensing data have different available period. Thus, it's necessary to match the 2 timeseries by time. For example, below is how we match observed data with remote sensing data.

# %%
obs_values=[]
for i in range(len(rs_ts)):
    month=rs_ts.iloc[i]['Month']
    year=rs_ts.iloc[i]['Year']
    obs_value=-9999
    #check if the month and year has observed data
    for j in range(len(obs_ts)):
        jline=obs_ts.iloc[j]
        if (year == jline['Year']) & (month == jline['Month']):        
            obs_value=jline['Data']    
        else:
            continue 
    obs_values.append(obs_value)
rs_ts['Observed']=obs_values
rs_ts
# Out:
#           Data  Month  Year  Observed
# 0    23.200001      1  2009       0.8
# 1    57.000000      2  2009      66.2
# 2    29.400000      3  2009      16.1
# 3     2.400000      4  2009       0.9
# 4     1.500000      5  2009       0.0
# 5     0.000000      6  2009       0.0
# 6     0.000000      7  2009       0.0
# 7     0.000000      8  2009       0.0
# 8     0.000000      9  2009       0.0
# 9     6.600000     10  2009       3.2
# 10   17.600000     11  2009      18.8
# 11   21.900000     12  2009      32.3
# 12   65.599998      1  2010      54.4
# 13   49.200001      2  2010      74.9
# 14   20.500000      3  2010      21.8
# 15    0.000000      4  2010       3.0
# 16    0.600000      5  2010       5.4
# 17    0.000000      6  2010       0.0
# 18    0.000000      7  2010       0.0
# 19    0.000000      8  2010       0.0
# 20    0.200000      9  2010       0.3
# 21    0.000000     10  2010       1.8
# 22    9.100000     11  2010       0.9
# 23   18.900000     12  2010      13.7
# 24   37.500000      1  2011      81.7
# 25   49.400002      2  2011      29.7
# 26   23.600000      3  2011       5.6
# 27    5.100000      4  2011      14.3
# 28    1.300000      5  2011       3.9
# 29    0.000000      6  2011       0.0
# ..         ...    ...   ...       ...
# 90    0.000000      7  2016   -9999.0
# 91    0.000000      8  2016   -9999.0
# 92    0.000000      9  2016   -9999.0
# 93    7.700000     10  2016   -9999.0
# 94   16.600000     11  2016   -9999.0
# 95   51.299999     12  2016   -9999.0
# 96   51.200001      1  2017   -9999.0
# 97   55.900002      2  2017   -9999.0
# 98   16.200001      3  2017   -9999.0
# 99    6.700000      4  2017   -9999.0
# 100   1.300000      5  2017   -9999.0
# 101   0.000000      6  2017   -9999.0
# 102   0.000000      7  2017   -9999.0
# 103   0.000000      8  2017   -9999.0
# 104   0.000000      9  2017   -9999.0
# 105   6.300000     10  2017   -9999.0
# 106  19.000000     11  2017   -9999.0
# 107  34.599998     12  2017   -9999.0
# 108  80.300003      1  2018   -9999.0
# 109  52.299999      2  2018   -9999.0
# 110  15.900000      3  2018   -9999.0
# 111   0.700000      4  2018   -9999.0
# 112   2.100000      5  2018   -9999.0
# 113   0.000000      6  2018   -9999.0
# 114   0.000000      7  2018   -9999.0
# 115   0.000000      8  2018   -9999.0
# 116   0.800000      9  2018   -9999.0
# 117   1.200000     10  2018   -9999.0
# 118  28.000000     11  2018   -9999.0
# 119  36.400002     12  2018   -9999.0
#
# [120 rows x 4 columns]

# %% [markdown]
# When there's remote sensing data but no observed data available (-9999 value), these values should be dropped out of analysis.

# %%
rs_ts.replace(-9999,np.nan)
rs_ts.drop(rs_ts.loc[rs_ts['Observed']==-9999].index,inplace=True)
rs_ts
# Out:
#          Data  Month  Year  Observed
# 0   23.200001      1  2009       0.8
# 1   57.000000      2  2009      66.2
# 2   29.400000      3  2009      16.1
# 3    2.400000      4  2009       0.9
# 4    1.500000      5  2009       0.0
# 5    0.000000      6  2009       0.0
# 6    0.000000      7  2009       0.0
# 7    0.000000      8  2009       0.0
# 8    0.000000      9  2009       0.0
# 9    6.600000     10  2009       3.2
# 10  17.600000     11  2009      18.8
# 11  21.900000     12  2009      32.3
# 12  65.599998      1  2010      54.4
# 13  49.200001      2  2010      74.9
# 14  20.500000      3  2010      21.8
# 15   0.000000      4  2010       3.0
# 16   0.600000      5  2010       5.4
# 17   0.000000      6  2010       0.0
# 18   0.000000      7  2010       0.0
# 19   0.000000      8  2010       0.0
# 20   0.200000      9  2010       0.3
# 21   0.000000     10  2010       1.8
# 22   9.100000     11  2010       0.9
# 23  18.900000     12  2010      13.7
# 24  37.500000      1  2011      81.7
# 25  49.400002      2  2011      29.7
# 26  23.600000      3  2011       5.6
# 27   5.100000      4  2011      14.3
# 28   1.300000      5  2011       3.9
# 29   0.000000      6  2011       0.0
# ..        ...    ...   ...       ...
# 58  12.600000     11  2013       0.6
# 59  63.799999     12  2013     146.0
# 60  28.500000      1  2014       4.7
# 61  26.000000      2  2014       3.2
# 62  78.900002      3  2014      69.6
# 63   4.200000      4  2014       0.0
# 64   1.900000      5  2014      35.1
# 65   0.000000      6  2014       0.0
# 66   0.000000      7  2014       0.0
# 67   0.000000      8  2014       0.0
# 68   0.000000      9  2014       0.0
# 69  10.100000     10  2014      11.6
# 70  43.200001     11  2014      36.3
# 71  29.200001     12  2014      12.9
# 72  82.300003      1  2015      86.9
# 73  81.300003      2  2015      85.5
# 74  16.500000      3  2015       6.6
# 75  10.400000      4  2015       9.1
# 76   0.000000      5  2015       0.4
# 77   0.000000      6  2015       0.0
# 78   0.000000      7  2015       0.0
# 79   0.000000      8  2015       0.0
# 80   0.000000      9  2015       0.0
# 81  16.200001     10  2015      22.8
# 82  24.799999     11  2015      27.2
# 83  38.299999     12  2015      43.7
# 84  84.800003      1  2016      77.9
# 85  50.500000      2  2016      45.4
# 86  32.500000      3  2016       9.8
# 87  12.700000      4  2016      28.0
#
# [88 rows x 4 columns]

# %% [markdown]
# One common method to validate remotely sensed data with observed data is using scatter plot and regression line.

# %%
from matplotlib import pyplot as plt
#plot scatter points
plt.scatter(rs_ts['Data'].values,rs_ts['Observed'].values)
plt.xlabel("WaPOR Precipitation [mm/month]")
plt.ylabel("Observed Precipitation [mm/month]")
plt.title(Station_name)

# regression line
#fitting RS and Observed data into a 1st order polynomial function (linear). z is the set of parameters of the fitted function
z = np.polyfit(rs_ts['Data'].values, rs_ts['Observed'].values, 1) 
#define the fitted linear function using parameter as p(x) where x is observed value
p = np.poly1d(z)
function = "%.2f * x+ (%.2f)"%(z[0],z[1]) 
#plot x=[0, max_x_value] and p(x)
plt.plot([0,max(rs_ts['Observed'])],p([0,max(rs_ts['Observed'])]),"r",label=function)
plt.legend(loc='upper left')

#adjust plot
plt.ylim(0,max(rs_ts['Observed']))
plt.xlim(0,max(rs_ts['Observed']))
plt.show()

# %% [markdown]
# ### Exercise (optional ++++)
# - Write a program to validate and bias-correct Remotely sensed precipitation data using observed data
# - Collect in-situ Precipitation data in your study area to validate a remote sensing product (Ex. WaPOR, TRMM)
# - Calculate Bias coefficient of remotely sensed data compare to observed data. Correct remotely sensed data if necessary (High bias value)

# %% [markdown]
# ## 2. Can RS-derived data close the water balance?
# A csv of yearly P, ET, and dS derived from GRACE of Litani basin, Lebanon was prepared. Annual P, ET can be computed using the exampled code from previous exercises. The dS (Total storage change) is calculated from GRACE GFSC Mascon solution. For more details, you can have a look at the given scripts in *GRACE_for_basin* folder.
# First, load the csv data as pandas Dataframe. The unit of the data values is MCM/year or Mm3/yr

# %%
import pandas as pd
Litani_csv=r"D:\FAO\Training\ETH_1907\Material\Data\Others\Litani\P_ET_dS_stats.csv"
df=pd.read_csv(Litani_csv,sep=';',index_col=0)
df
# Out:
#    year         P           ET   dS
# 0  2010  1387.340  1049.236000  -70
# 1  2011  1376.750   927.632158  -77
# 2  2012  1775.850   932.551200   38
# 3  2013  1612.000  1039.102000  -83
# 4  2014   992.138   713.588700  -28
# 5  2015  1153.029   829.601700 -106
# 6  2016  1292.685   785.900000  -41

# %% [markdown]
# We can calculate a new column as function of existing columns using the dataframe method *apply*
#
# *df.apply(**lamda** row: function(row['column1'],row['column2'],...), axis=1)*
#
# For example, below is how to calculate new column P-ET-dS

# %%
df['P-ET-dS']=df.apply(lambda row: row['P'] - row['ET'] - row['dS'], axis=1)
df
# Out:
#    year         P           ET   dS     P-ET-dS
# 0  2010  1387.340  1049.236000  -70  408.104000
# 1  2011  1376.750   927.632158  -77  526.117842
# 2  2012  1775.850   932.551200   38  805.298800
# 3  2013  1612.000  1039.102000  -83  655.898000
# 4  2014   992.138   713.588700  -28  306.549300
# 5  2015  1153.029   829.601700 -106  429.427300
# 6  2016  1292.685   785.900000  -41  547.785000

# %% [markdown]
# Discharges were measured at the outlet of Litani basin and stored in a csv file. To compare the yearly discharge at outlet, we need to read the data from csv file and convert into yearly data.

# %%
Qoutlet_csv=r"D:\FAO\Training\ETH_1907\Material\Data\Others\Litani\Qoutlet_litani.csv"
Qoutlet=pd.read_csv(Qoutlet_csv,sep=';',index_col=0,skiprows=1)
Qoutlet
# Out:
#                   year  month  day       m3/s  km3/month  days
# datetime
# 01/01/2010 00:00  2010      1    1  16.859613   0.045157    31
# 01/02/2010 00:00  2010      2    1  15.560821   0.037645    28
# 01/03/2010 00:00  2010      3    1  21.270065   0.056970    31
# 01/04/2010 00:00  2010      4    1   9.422667   0.024424    30
# 01/05/2010 00:00  2010      5    1   2.005290   0.005371    31
# 01/06/2010 00:00  2010      6    1   0.171233   0.000444    30
# 01/07/2010 00:00  2010      7    1   0.111000   0.000297    31
# 01/08/2010 00:00  2010      8    1   0.049742   0.000133    31
# 01/09/2010 00:00  2010      9    1   1.275767   0.003307    30
# 01/10/2010 00:00  2010     10    1   1.295968   0.003471    31
# 01/11/2010 00:00  2010     11    1   1.321500   0.003425    30
# 01/12/2010 00:00  2010     12    1   1.275323   0.003416    31
# 01/01/2011 00:00  2011      1    1   1.322226   0.003541    31
# 01/02/2011 00:00  2011      2    1  16.010679   0.038733    28
# 01/03/2011 00:00  2011      3    1  25.507548   0.068319    31
# 01/04/2011 00:00  2011      4    1  11.943733   0.030958    30
# 01/05/2011 00:00  2011      5    1   4.294903   0.011503    31
# 01/06/2011 00:00  2011      6    1   1.241033   0.003217    30
# 01/07/2011 00:00  2011      7    1   1.201226   0.003217    31
# 01/08/2011 00:00  2011      8    1   1.223645   0.003277    31
# 01/09/2011 00:00  2011      9    1   0.216467   0.000561    30
# 01/10/2011 00:00  2011     10    1   0.231226   0.000619    31
# 01/11/2011 00:00  2011     11    1   3.917333   0.010154    30
# 01/12/2011 00:00  2011     12    1   7.865871   0.021068    31
# 01/01/2012 00:00  2012      1    1  18.810548   0.050382    31
# 01/02/2012 00:00  2012      2    1  26.174448   0.065583    29
# 01/03/2012 00:00  2012      3    1  43.235290   0.115801    31
# 01/04/2012 00:00  2012      4    1  23.709667   0.061455    30
# 01/05/2012 00:00  2012      5    1   7.681677   0.020575    31
# 01/06/2012 00:00  2012      6    1   4.936933   0.012797    30
# ...                ...    ...  ...        ...        ...   ...
# 01/07/2014 00:00  2014      7    1   0.000000   0.000000    31
# 01/08/2014 00:00  2014      8    1   0.000000   0.000000    31
# 01/09/2014 00:00  2014      9    1   0.000000   0.000000    30
# 01/10/2014 00:00  2014     10    1   0.968000   0.002593    31
# 01/11/2014 00:00  2014     11    1   1.667000   0.004321    30
# 01/12/2014 00:00  2014     12    1   5.323000   0.014257    31
# 01/01/2015 00:00  2015      1    1  14.677000   0.039311    31
# 01/02/2015 00:00  2015      2    1  16.071000   0.038879    28
# 01/03/2015 00:00  2015      3    1  15.000000   0.040176    31
# 01/04/2015 00:00  2015      4    1  11.000000   0.028512    30
# 01/05/2015 00:00  2015      5    1   2.903000   0.007775    31
# 01/06/2015 00:00  2015      6    1   0.167000   0.000433    30
# 01/07/2015 00:00  2015      7    1   0.161000   0.000431    31
# 01/08/2015 00:00  2015      8    1   0.161000   0.000431    31
# 01/09/2015 00:00  2015      9    1   0.014000   0.000036    30
# 01/10/2015 00:00  2015     10    1   0.104000   0.000279    31
# 01/11/2015 00:00  2015     11    1   2.120000   0.005495    30
# 01/12/2015 00:00  2015     12    1   2.401000   0.006431    31
# 01/01/2016 00:00  2016      1    1   8.117000   0.021741    31
# 01/02/2016 00:00  2016      2    1   8.745000   0.021156    28
# 01/03/2016 00:00  2016      3    1   6.323000   0.016936    31
# 01/04/2016 00:00  2016      4    1   5.067000   0.013134    30
# 01/05/2016 00:00  2016      5    1   0.672000   0.001800    31
# 01/06/2016 00:00  2016      6    1   0.094000   0.000244    30
# 01/07/2016 00:00  2016      7    1   0.130000   0.000348    31
# 01/08/2016 00:00  2016      8    1   0.000000   0.000000    31
# 01/09/2016 00:00  2016      9    1   0.140000   0.000363    30
# 01/10/2016 00:00  2016     10    1   0.235000   0.000629    31
# 01/11/2016 00:00  2016     11    1   0.220000   0.000570    30
# 01/12/2016 00:00  2016     12    1   5.458000   0.014619    31
#
# [84 rows x 6 columns]

# %% [markdown]
# Always check for nodata values and exclude them from calculation.

# %%
Qoutlet.drop(Qoutlet.loc[Qoutlet['m3/s']==-9999].index,inplace=True)
Qoutlet
# Out:
#                   year  month  day       m3/s  km3/month  days
# datetime
# 01/01/2010 00:00  2010      1    1  16.859613   0.045157    31
# 01/02/2010 00:00  2010      2    1  15.560821   0.037645    28
# 01/03/2010 00:00  2010      3    1  21.270065   0.056970    31
# 01/04/2010 00:00  2010      4    1   9.422667   0.024424    30
# 01/05/2010 00:00  2010      5    1   2.005290   0.005371    31
# 01/06/2010 00:00  2010      6    1   0.171233   0.000444    30
# 01/07/2010 00:00  2010      7    1   0.111000   0.000297    31
# 01/08/2010 00:00  2010      8    1   0.049742   0.000133    31
# 01/09/2010 00:00  2010      9    1   1.275767   0.003307    30
# 01/10/2010 00:00  2010     10    1   1.295968   0.003471    31
# 01/11/2010 00:00  2010     11    1   1.321500   0.003425    30
# 01/12/2010 00:00  2010     12    1   1.275323   0.003416    31
# 01/01/2011 00:00  2011      1    1   1.322226   0.003541    31
# 01/02/2011 00:00  2011      2    1  16.010679   0.038733    28
# 01/03/2011 00:00  2011      3    1  25.507548   0.068319    31
# 01/04/2011 00:00  2011      4    1  11.943733   0.030958    30
# 01/05/2011 00:00  2011      5    1   4.294903   0.011503    31
# 01/06/2011 00:00  2011      6    1   1.241033   0.003217    30
# 01/07/2011 00:00  2011      7    1   1.201226   0.003217    31
# 01/08/2011 00:00  2011      8    1   1.223645   0.003277    31
# 01/09/2011 00:00  2011      9    1   0.216467   0.000561    30
# 01/10/2011 00:00  2011     10    1   0.231226   0.000619    31
# 01/11/2011 00:00  2011     11    1   3.917333   0.010154    30
# 01/12/2011 00:00  2011     12    1   7.865871   0.021068    31
# 01/01/2012 00:00  2012      1    1  18.810548   0.050382    31
# 01/02/2012 00:00  2012      2    1  26.174448   0.065583    29
# 01/03/2012 00:00  2012      3    1  43.235290   0.115801    31
# 01/04/2012 00:00  2012      4    1  23.709667   0.061455    30
# 01/05/2012 00:00  2012      5    1   7.681677   0.020575    31
# 01/06/2012 00:00  2012      6    1   4.936933   0.012797    30
# ...                ...    ...  ...        ...        ...   ...
# 01/07/2014 00:00  2014      7    1   0.000000   0.000000    31
# 01/08/2014 00:00  2014      8    1   0.000000   0.000000    31
# 01/09/2014 00:00  2014      9    1   0.000000   0.000000    30
# 01/10/2014 00:00  2014     10    1   0.968000   0.002593    31
# 01/11/2014 00:00  2014     11    1   1.667000   0.004321    30
# 01/12/2014 00:00  2014     12    1   5.323000   0.014257    31
# 01/01/2015 00:00  2015      1    1  14.677000   0.039311    31
# 01/02/2015 00:00  2015      2    1  16.071000   0.038879    28
# 01/03/2015 00:00  2015      3    1  15.000000   0.040176    31
# 01/04/2015 00:00  2015      4    1  11.000000   0.028512    30
# 01/05/2015 00:00  2015      5    1   2.903000   0.007775    31
# 01/06/2015 00:00  2015      6    1   0.167000   0.000433    30
# 01/07/2015 00:00  2015      7    1   0.161000   0.000431    31
# 01/08/2015 00:00  2015      8    1   0.161000   0.000431    31
# 01/09/2015 00:00  2015      9    1   0.014000   0.000036    30
# 01/10/2015 00:00  2015     10    1   0.104000   0.000279    31
# 01/11/2015 00:00  2015     11    1   2.120000   0.005495    30
# 01/12/2015 00:00  2015     12    1   2.401000   0.006431    31
# 01/01/2016 00:00  2016      1    1   8.117000   0.021741    31
# 01/02/2016 00:00  2016      2    1   8.745000   0.021156    28
# 01/03/2016 00:00  2016      3    1   6.323000   0.016936    31
# 01/04/2016 00:00  2016      4    1   5.067000   0.013134    30
# 01/05/2016 00:00  2016      5    1   0.672000   0.001800    31
# 01/06/2016 00:00  2016      6    1   0.094000   0.000244    30
# 01/07/2016 00:00  2016      7    1   0.130000   0.000348    31
# 01/08/2016 00:00  2016      8    1   0.000000   0.000000    31
# 01/09/2016 00:00  2016      9    1   0.140000   0.000363    30
# 01/10/2016 00:00  2016     10    1   0.235000   0.000629    31
# 01/11/2016 00:00  2016     11    1   0.220000   0.000570    30
# 01/12/2016 00:00  2016     12    1   5.458000   0.014619    31
#
# [84 rows x 6 columns]

# %% [markdown]
# Using the *apply* method, convert discharge in m3/s to Mm3.

# %%
Qoutlet['Mm3']=Qoutlet.apply(lambda row: (row['m3/s']*86400*row['days'])/(1000000), axis=1)
Qoutlet
# Out:
#                   year  month  day       m3/s  km3/month  days         Mm3
# datetime
# 01/01/2010 00:00  2010      1    1  16.859613   0.045157    31   45.156787
# 01/02/2010 00:00  2010      2    1  15.560821   0.037645    28   37.644739
# 01/03/2010 00:00  2010      3    1  21.270065   0.056970    31   56.969741
# 01/04/2010 00:00  2010      4    1   9.422667   0.024424    30   24.423552
# 01/05/2010 00:00  2010      5    1   2.005290   0.005371    31    5.370970
# 01/06/2010 00:00  2010      6    1   0.171233   0.000444    30    0.443837
# 01/07/2010 00:00  2010      7    1   0.111000   0.000297    31    0.297302
# 01/08/2010 00:00  2010      8    1   0.049742   0.000133    31    0.133229
# 01/09/2010 00:00  2010      9    1   1.275767   0.003307    30    3.306787
# 01/10/2010 00:00  2010     10    1   1.295968   0.003471    31    3.471120
# 01/11/2010 00:00  2010     11    1   1.321500   0.003425    30    3.425328
# 01/12/2010 00:00  2010     12    1   1.275323   0.003416    31    3.415824
# 01/01/2011 00:00  2011      1    1   1.322226   0.003541    31    3.541450
# 01/02/2011 00:00  2011      2    1  16.010679   0.038733    28   38.733034
# 01/03/2011 00:00  2011      3    1  25.507548   0.068319    31   68.319418
# 01/04/2011 00:00  2011      4    1  11.943733   0.030958    30   30.958157
# 01/05/2011 00:00  2011      5    1   4.294903   0.011503    31   11.503469
# 01/06/2011 00:00  2011      6    1   1.241033   0.003217    30    3.216758
# 01/07/2011 00:00  2011      7    1   1.201226   0.003217    31    3.217363
# 01/08/2011 00:00  2011      8    1   1.223645   0.003277    31    3.277411
# 01/09/2011 00:00  2011      9    1   0.216467   0.000561    30    0.561082
# 01/10/2011 00:00  2011     10    1   0.231226   0.000619    31    0.619315
# 01/11/2011 00:00  2011     11    1   3.917333   0.010154    30   10.153728
# 01/12/2011 00:00  2011     12    1   7.865871   0.021068    31   21.067949
# 01/01/2012 00:00  2012      1    1  18.810548   0.050382    31   50.382173
# 01/02/2012 00:00  2012      2    1  26.174448   0.065583    29   65.582698
# 01/03/2012 00:00  2012      3    1  43.235290   0.115801    31  115.801402
# 01/04/2012 00:00  2012      4    1  23.709667   0.061455    30   61.455456
# 01/05/2012 00:00  2012      5    1   7.681677   0.020575    31   20.574605
# 01/06/2012 00:00  2012      6    1   4.936933   0.012797    30   12.796531
# ...                ...    ...  ...        ...        ...   ...         ...
# 01/07/2014 00:00  2014      7    1   0.000000   0.000000    31    0.000000
# 01/08/2014 00:00  2014      8    1   0.000000   0.000000    31    0.000000
# 01/09/2014 00:00  2014      9    1   0.000000   0.000000    30    0.000000
# 01/10/2014 00:00  2014     10    1   0.968000   0.002593    31    2.592691
# 01/11/2014 00:00  2014     11    1   1.667000   0.004321    30    4.320864
# 01/12/2014 00:00  2014     12    1   5.323000   0.014257    31   14.257123
# 01/01/2015 00:00  2015      1    1  14.677000   0.039311    31   39.310877
# 01/02/2015 00:00  2015      2    1  16.071000   0.038879    28   38.878963
# 01/03/2015 00:00  2015      3    1  15.000000   0.040176    31   40.176000
# 01/04/2015 00:00  2015      4    1  11.000000   0.028512    30   28.512000
# 01/05/2015 00:00  2015      5    1   2.903000   0.007775    31    7.775395
# 01/06/2015 00:00  2015      6    1   0.167000   0.000433    30    0.432864
# 01/07/2015 00:00  2015      7    1   0.161000   0.000431    31    0.431222
# 01/08/2015 00:00  2015      8    1   0.161000   0.000431    31    0.431222
# 01/09/2015 00:00  2015      9    1   0.014000   0.000036    30    0.036288
# 01/10/2015 00:00  2015     10    1   0.104000   0.000279    31    0.278554
# 01/11/2015 00:00  2015     11    1   2.120000   0.005495    30    5.495040
# 01/12/2015 00:00  2015     12    1   2.401000   0.006431    31    6.430838
# 01/01/2016 00:00  2016      1    1   8.117000   0.021741    31   21.740573
# 01/02/2016 00:00  2016      2    1   8.745000   0.021156    28   21.155904
# 01/03/2016 00:00  2016      3    1   6.323000   0.016936    31   16.935523
# 01/04/2016 00:00  2016      4    1   5.067000   0.013134    30   13.133664
# 01/05/2016 00:00  2016      5    1   0.672000   0.001800    31    1.799885
# 01/06/2016 00:00  2016      6    1   0.094000   0.000244    30    0.243648
# 01/07/2016 00:00  2016      7    1   0.130000   0.000348    31    0.348192
# 01/08/2016 00:00  2016      8    1   0.000000   0.000000    31    0.000000
# 01/09/2016 00:00  2016      9    1   0.140000   0.000363    30    0.362880
# 01/10/2016 00:00  2016     10    1   0.235000   0.000629    31    0.629424
# 01/11/2016 00:00  2016     11    1   0.220000   0.000570    30    0.570240
# 01/12/2016 00:00  2016     12    1   5.458000   0.014619    31   14.618707
#
# [84 rows x 7 columns]

# %% [markdown]
# Remember how to sum data by year?

# %%
Qoutlet_y=Qoutlet.groupby(['year']).sum()
Qoutlet_y
# Out:
#       month  day        m3/s  km3/month  days         Mm3
# year
# 2010     78   12   70.618988   0.184059   365  184.059216
# 2011     78   12   74.975890   0.195169   365  195.169133
# 2012     78   12  137.816463   0.362003   366  362.003126
# 2013     78   12   75.646636   0.197106   365  197.105962
# 2014     78   12   24.170000   0.063410   365   63.409997
# 2015     78   12   64.779000   0.168189   365  168.189264
# 2016     78   12   35.201000   0.091539   365   91.538640

# %% [markdown]
# Now we can compare Qoutlet with P-ET-dS of Litani basin. What does it mean when P-ET-dS is not close to Qoutlet?

# %%
df['Qoutlet']=Qoutlet_y['Mm3'].values
from matplotlib import pyplot as plt
ax = plt.subplot(111)
ax.plot(df['P-ET-dS'].values,label='P-ET-dS')
ax.plot(df['Qoutlet'].values,label='Qoutlet')
ax.legend()
ax.set_xticklabels(df['year'].values)
ax.set_xlabel('Time')
ax.set_ylabel('Flows [MCM/year]')
plt.show()

# %% [markdown]
# ### Exercise (++):
# One of the reasons for the gap between remotely sensed water balance and in-situ measured discharge at outlet is unaccounted flows such as inter-basin transfer.
# For Litani basin, this is the case. A great amount of water is transfered out of the basin from a reservoir before the outlet. Given the recorded monthly inter-basin transfer from 2010 to 2016 (**Qibt_litani.csv**), use this data to check the Water Balance of Litani.
#
# **Hint**:
# Make use of the example codes to calculate yearly inter-basin transfer. For the years with no data available, use average value of all years for example.

# %%
Qibt_csv=r"D:\FAO\Training\ETH_1907\Material\Data\Others\Litani\Qibt_litani.csv"
Qibt=pd.read_csv(Qibt_csv,sep=';',index_col=0,skiprows=1)
Qibt
# Out:
#                   year  month  day       m3/s  km3/month  days
# datetime
# 01/01/2010 00:00  2010      1    1  16.859613   0.045157    31
# 01/02/2010 00:00  2010      2    1  15.560821   0.037645    28
# 01/03/2010 00:00  2010      3    1  21.270065   0.056970    31
# 01/04/2010 00:00  2010      4    1   9.422667   0.024424    30
# 01/05/2010 00:00  2010      5    1   2.005290   0.005371    31
# 01/06/2010 00:00  2010      6    1   0.171233   0.000444    30
# 01/07/2010 00:00  2010      7    1   0.111000   0.000297    31
# 01/08/2010 00:00  2010      8    1   0.049742   0.000133    31
# 01/09/2010 00:00  2010      9    1   1.275767   0.003307    30
# 01/10/2010 00:00  2010     10    1   1.295968   0.003471    31
# 01/11/2010 00:00  2010     11    1   1.321500   0.003425    30
# 01/12/2010 00:00  2010     12    1   1.275323   0.003416    31
# 01/01/2011 00:00  2011      1    1   1.322226   0.003541    31
# 01/02/2011 00:00  2011      2    1  16.010679   0.038733    28
# 01/03/2011 00:00  2011      3    1  25.507548   0.068319    31
# 01/04/2011 00:00  2011      4    1  11.943733   0.030958    30
# 01/05/2011 00:00  2011      5    1   4.294903   0.011503    31
# 01/06/2011 00:00  2011      6    1   1.241033   0.003217    30
# 01/07/2011 00:00  2011      7    1   1.201226   0.003217    31
# 01/08/2011 00:00  2011      8    1   1.223645   0.003277    31
# 01/09/2011 00:00  2011      9    1   0.216467   0.000561    30
# 01/10/2011 00:00  2011     10    1   0.231226   0.000619    31
# 01/11/2011 00:00  2011     11    1   3.917333   0.010154    30
# 01/12/2011 00:00  2011     12    1   7.865871   0.021068    31
# 01/01/2012 00:00  2012      1    1  18.810548   0.050382    31
# 01/02/2012 00:00  2012      2    1  26.174448   0.065583    29
# 01/03/2012 00:00  2012      3    1  43.235290   0.115801    31
# 01/04/2012 00:00  2012      4    1  23.709667   0.061455    30
# 01/05/2012 00:00  2012      5    1   7.681677   0.020575    31
# 01/06/2012 00:00  2012      6    1   4.936933   0.012797    30
# ...                ...    ...  ...        ...        ...   ...
# 01/07/2014 00:00  2014      7    1   0.000000   0.000000    31
# 01/08/2014 00:00  2014      8    1   0.000000   0.000000    31
# 01/09/2014 00:00  2014      9    1   0.000000   0.000000    30
# 01/10/2014 00:00  2014     10    1   0.968000   0.002593    31
# 01/11/2014 00:00  2014     11    1   1.667000   0.004321    30
# 01/12/2014 00:00  2014     12    1   5.323000   0.014257    31
# 01/01/2015 00:00  2015      1    1  14.677000   0.039311    31
# 01/02/2015 00:00  2015      2    1  16.071000   0.038879    28
# 01/03/2015 00:00  2015      3    1  15.000000   0.040176    31
# 01/04/2015 00:00  2015      4    1  11.000000   0.028512    30
# 01/05/2015 00:00  2015      5    1   2.903000   0.007775    31
# 01/06/2015 00:00  2015      6    1   0.167000   0.000433    30
# 01/07/2015 00:00  2015      7    1   0.161000   0.000431    31
# 01/08/2015 00:00  2015      8    1   0.161000   0.000431    31
# 01/09/2015 00:00  2015      9    1   0.014000   0.000036    30
# 01/10/2015 00:00  2015     10    1   0.104000   0.000279    31
# 01/11/2015 00:00  2015     11    1   2.120000   0.005495    30
# 01/12/2015 00:00  2015     12    1   2.401000   0.006431    31
# 01/01/2016 00:00  2016      1    1   8.117000   0.021741    31
# 01/02/2016 00:00  2016      2    1   8.745000   0.021156    28
# 01/03/2016 00:00  2016      3    1   6.323000   0.016936    31
# 01/04/2016 00:00  2016      4    1   5.067000   0.013134    30
# 01/05/2016 00:00  2016      5    1   0.672000   0.001800    31
# 01/06/2016 00:00  2016      6    1   0.094000   0.000244    30
# 01/07/2016 00:00  2016      7    1   0.130000   0.000348    31
# 01/08/2016 00:00  2016      8    1   0.000000   0.000000    31
# 01/09/2016 00:00  2016      9    1   0.140000   0.000363    30
# 01/10/2016 00:00  2016     10    1   0.235000   0.000629    31
# 01/11/2016 00:00  2016     11    1   0.220000   0.000570    30
# 01/12/2016 00:00  2016     12    1   5.458000   0.014619    31
#
# [84 rows x 6 columns]

# %% [markdown]
# ### Exercise (optional +++)
# - Extract dS timeseries for Awash (Given: shapefile, GRACE MASCON)
# - Derive yearly dS of Awash
# - Estimate the water balance residual (P-ET-dS) of Awash for a chosen year (or all the years with available GRACE data).
